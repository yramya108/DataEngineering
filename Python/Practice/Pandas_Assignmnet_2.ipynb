# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
customer_shopping_data=pd.read_csv("C:/Users/eyamram/OneDrive - Ericsson/Documents/Ramya_study/EduKron/Python/Python_Datasets/customer_shopping_data.csv")
df = pd.DataFrame(customer_shopping_data)

# %%
df
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
transaction_counts = df["shopping_mall"].value_counts()

# %%
transaction_counts
# Out:
# shopping_mall
# Mall of Istanbul     19943
# Kanyon               19823
# Metrocity            15011
# Metropol AVM         10161
# Istinye Park          9781
# Zorlu Center          5075
# Cevahir AVM           4991
# Forum Istanbul        4947
# Viaport Outlet        4914
# Emaar Square Mall     4811
# Name: count, dtype: int64

# %%
plt.bar(transaction_counts.index, transaction_counts.values, color="limegreen")
plt.title("Shopping malls")
plt.xlabel("Names of Malls")
plt.ylabel("Value Count")
plt.xticks(rotation=50)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# %%
df['invoice_date'] = pd.to_datetime(df['invoice_date'],dayfirst=True)

# %%
df
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
df['month'] = pd.to_datetime(df['invoice_date']).dt.month

# %%
df
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
data = {
    "invoice_date": ["2023-04-01", "2023-04-01", "2023-04-02", "2023-04-02", "2023-04-03"],
    "revenue": [100, 150, 200, 250, 300],
}
df1 = pd.DataFrame(data)

# %%
df1["invoice_date"] = pd.to_datetime(df1["invoice_date"])

# %%
daily_revenue = df1.groupby("invoice_date")["revenue"].sum().reset_index()

# %%
plt.figure(figsize=(10, 6))
plt.plot(daily_revenue["invoice_date"], daily_revenue["revenue"], marker="o", linestyle="-", color="blue")
plt.title("Daily Revenue Trends", fontsize=16)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Revenue", fontsize=12)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df['total_price'] = df['quantity']* df['price']
print(df)
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
customer_daily_revenue= df.groupby("invoice_date")["total_price"].sum().reset_index()

# %%
plt.figure(figsize=(10, 6))
plt.plot(customer_daily_revenue["invoice_date"], customer_daily_revenue["total_price"], marker="o", linestyle="-", color="blue")
plt.title("Daily Revenue Trends", fontsize=16)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Revenue", fontsize=12)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df['date'] = pd.to_datetime(df['invoice_date'])
df['day_of_week'] = df['date'].dt.day_name()
print(df.head(5))
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall  month       date day_of_week
# 0    Credit Card   2022-08-05          Kanyon      8 2022-08-05      Friday
# 1     Debit Card   2021-12-12  Forum Istanbul     12 2021-12-12      Sunday
# 2           Cash   2021-11-09       Metrocity     11 2021-11-09     Tuesday
# 3    Credit Card   2021-05-16    Metropol AVM      5 2021-05-16      Sunday
# 4           Cash   2021-10-24          Kanyon     10 2021-10-24      Sunday

# %%
transactions_by_day = df["day_of_week"].value_counts()

# %%
transactions_by_day
# Out:
# day_of_week
# Monday       14383
# Friday       14347
# Tuesday      14217
# Sunday       14140
# Thursday     14129
# Saturday     14121
# Wednesday    14120
# Name: count, dtype: int64

# %%
most_transactions_day = transactions_by_day.idxmax()
most_transactions_count = transactions_by_day.max()

# %%
print(f"most_transactions_day :{most_transactions_day} , most_transactions_count : {most_transactions_count}")
# Out:
# most_transactions_day :Monday , most_transactions_count : 14383

# %%
bins1 = [0,20,40,60]
lables1 = ['0-20','21-40','41-60','61+']
df['age_bins'] = pd.cut(df['age'],bins=bins1, labels=lables1)
print(df['age_bins'] )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 3
#       1 bins1 = [0,20,40,60]
#       2 lables1 = ['0-20','21-40','41-60','61+']
# ----> 3 df['age_bins'] = pd.cut(df['age'],bins=bins1, labels=lables1)
#       4 print(df['age_bins'] )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\reshape\tile.py:257, in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     254     if not bins.is_monotonic_increasing:
#     255         raise ValueError("bins must increase monotonically.")
# --> 257 fac, bins = _bins_to_cuts(
#     258     x_idx,
#     259     bins,
#     260     right=right,
#     261     labels=labels,
#     262     precision=precision,
#     263     include_lowest=include_lowest,
#     264     duplicates=duplicates,
#     265     ordered=ordered,
#     266 )
# ...
